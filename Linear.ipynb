# %%
import pandas as pd
import numpy as np

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('/content/canada_per_capita_income.csv')

# %%
df.head()
# Out:
#    year  per capita income (US$)
# 0  1970              3399.299037
# 1  1971              3768.297935
# 2  1972              4251.175484
# 3  1973              4804.463248
# 4  1974              5576.514583

# %%
df.isnull().sum()
# Out:
# year                       0
# per capita income (US$)    0
# dtype: int64

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()
model.fit(df[['year']],df['per capita income (US$)'])
# Out:
# LinearRegression()

# %%
accuracy_score = model.score(df[['year']],df['per capita income (US$)'])
print(accuracy_score)
# Out:
# 0.890916917957032

# %%
model.predict([[1971]])
# Out:
# array([693.9054085])

# %%
model.score(df[['year']],df['per capita income (US$)'])
# Out:
# 0.890916917957032

# %%
model.coef_
# Out:
# array([828.46507522])

# %%
model.intercept_
# Out:
# np.float64(-1632210.7578554575)

# %%
model.predict([[2020]])
# Out:
# array([41288.69409442])

# %%
model.predict([[2018]])
# Out:
# array([39631.76394397])
